# %% [markdown]
# # Kaggle House Prices

# %% [markdown]
# ### Import des librairies

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import warnings
from scipy.stats import kurtosis, skew
from scipy import stats

# %matplotlib inline
warnings.filterwarnings(action='once')

# %% [markdown]
# ### Chargement des csv/datafiles :

# %%
trainfull = pd.read_csv('data/train.csv')
testfull = pd.read_csv('data/test.csv')

# %% [markdown]
# ### 1ères informations

# %% [markdown]
# Les dimensions de nos datafiles:

# %%
print("trainfull : " + str(trainfull.shape))
print("testfull : " + str(testfull.shape))
# Out:
# trainfull : (1460, 81)
# testfull : (1459, 80)

# %% [markdown]
# Soit :<br>
#     1460 lignes (entrées) et 81 colonnes (features) pour le trainfull.<br>
#     1459 lignes (entrées) et 80 colonnes (features) pour le testfull.<br>

# %%
trainfull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# 1. On a donc 2 types de variables. Les variables **qualitatives**(*object*) et des **numériques** (*float64* et *int64*).<br><br>
# 2. Certaines variables ne sont pas pertinentes ou importantes. Les nombres de la 2ème colonne indique combien les features contiennent des éléments. Cela signifie qu'il ne compte que les éléments réels et élimine ceux qui contiennent des informations manquantes.<br>
# Ici, on peut voir qu' `Alley`, `PoolQC` et `MiscFeature` ont respectivement que 91, 7 et 54 lignes remplies. On peut donc les considérer comme des features non importantes et les supprimer.<br>

# %% [markdown]
# Définissons un nouveau dataset`train` dans lequel le nombre total d'éléments réels dans les colonnes est supérieur ou égal à 30%.

# %%
train = trainfull[[column for column in trainfull if trainfull[column].count() / len(trainfull) >= 0.3]]

del train['Id']
print("List of dropped columns:", end=" ")
for c in trainfull.columns:
    if c not in train.columns:
        print(c, end=", ")
print('\n')
# Out:
# List of dropped columns: Id, Alley, PoolQC, Fence, MiscFeature,

# %% [markdown]
# Nous devons faire la même chose pour le dataset `test`

# %%
test = testfull[[column for column in testfull if testfull[column].count() / len(testfull) >= 0.3]]

test_id = test['Id']

del test['Id']
print("List of dropped columns:", end=" ")
for c in testfull.columns:
    if c not in test.columns:
        print(c, end=", ")
print('\n')
# Out:
# List of dropped columns: Id, Alley, PoolQC, Fence, MiscFeature,

# %%
print ("Size of train data : {}" .format(train.shape))
train.get_dtype_counts()
print ("Size of test data : {}" .format(test.shape))
test.get_dtype_counts()
# Out:
# Size of train data : (1460, 76)
# Size of test data : (1459, 75)
# int64      25
# object     39
# float64    11
# dtype: int64

# %% [markdown]
# Il nous reste donc 76 features dont 37 numériques et 39 catégorielles.

# %% [markdown]
# On peut sauvegarder le dataset`train` en csv qui nous servira à l'exploration des données plus en profondeur.

# %% [markdown]
# Traitons maintenant les valeurs manquantes pour les autres features.

# %% [markdown]
# ## Traitement des valeurs nulles - `Train`

# %%
# fonction pour les valeurs manquantes
def null_values(df):
    
    sum_null = df.isnull().sum()
    total = df.isnull().count()
    percent_nullvalues = 100* sum_null / total
    df_null = pd.DataFrame()
    df_null['Total'] = total
    df_null['Null_Count'] = sum_null
    df_null['Percent'] = round(percent_nullvalues,2)
    df_null['Type'] = df.loc[:, df.columns.isin(list(df.isnull()))].dtypes
    df_null = df_null.sort_values(by='Null_Count',ascending = False)
    df_null = df_null[df_null.Null_Count > 0]
    
    return(df_null)

# %%
null_values(train)
# Out:
#               Total  Null_Count  Percent     Type
# FireplaceQu    1460         690    47.26   object
# LotFrontage    1460         259    17.74  float64
# GarageType     1460          81     5.55   object
# GarageYrBlt    1460          81     5.55  float64
# GarageFinish   1460          81     5.55   object
# GarageQual     1460          81     5.55   object
# GarageCond     1460          81     5.55   object
# BsmtExposure   1460          38     2.60   object
# BsmtFinType2   1460          38     2.60   object
# BsmtQual       1460          37     2.53   object
# BsmtCond       1460          37     2.53   object
# BsmtFinType1   1460          37     2.53   object
# MasVnrType     1460           8     0.55   object
# MasVnrArea     1460           8     0.55  float64
# Electrical     1460           1     0.07   object

# %% [markdown]
# On observe aussi qu'`Electrical` n'a qu'une seule valeur manquante. On peut la remplacer par la valeur qui se répète le plus.

# %%
print('Categories for Electrical variable:')
print(train['Electrical'].value_counts())
# Out:
# Categories for Electrical variable:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %% [markdown]
# On observe que la valeur `SBrkr` est la plus représentée. On remplace la valeur manquante par celle-ci.

# %%
train['Electrical'] = train['Electrical'].fillna('SBrkr')
# Out:
# c:\users\utilisateur\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Pour les features numériques nous allons remplacer les valeurs manquantes par *0*.<br>
# Pour les features catégorielles nous allons remplacer les valeurs manquantes par *None*.

# %% [markdown]
# Variables quantitatives :

# %%
for col in ('LotFrontage', 'GarageYrBlt', 'MasVnrArea'):
    train[col] = train[col].fillna(0)
# Out:
# c:\users\utilisateur\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Variables qualitatives :

# %%
for col in ('FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
            'GarageCond', 'BsmtExposure', 'BsmtFinType2', 'BsmtQual',
            'BsmtCond', 'BsmtFinType1', 'MasVnrType' ):
    train[col] = train[col].fillna('None')
# Out:
# c:\users\utilisateur\python\python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
null_values(train)
# Out:
# Empty DataFrame
# Columns: [Total, Null_Count, Percent, Type]
# Index: []

# %% [markdown]
# Nous n'avons plus aucune valeur nulle dans notre dataset.

# %% [markdown]
# # Traitement des valeurs nulles - `Test`

# %%
test_null = null_values(test)
test_null
# Out:
#               Total  Null_Count  Percent     Type
# FireplaceQu    1459         730    50.03   object
# LotFrontage    1459         227    15.56  float64
# GarageQual     1459          78     5.35   object
# GarageFinish   1459          78     5.35   object
# GarageCond     1459          78     5.35   object
# GarageYrBlt    1459          78     5.35  float64
# GarageType     1459          76     5.21   object
# BsmtCond       1459          45     3.08   object
# BsmtExposure   1459          44     3.02   object
# BsmtQual       1459          44     3.02   object
# BsmtFinType1   1459          42     2.88   object
# BsmtFinType2   1459          42     2.88   object
# MasVnrType     1459          16     1.10   object
# MasVnrArea     1459          15     1.03  float64
# MSZoning       1459           4     0.27   object
# BsmtHalfBath   1459           2     0.14  float64
# Functional     1459           2     0.14   object
# BsmtFullBath   1459           2     0.14  float64
# Utilities      1459           2     0.14   object
# GarageCars     1459           1     0.07  float64
# KitchenQual    1459           1     0.07   object
# SaleType       1459           1     0.07   object
# TotalBsmtSF    1459           1     0.07  float64
# BsmtUnfSF      1459           1     0.07  float64
# BsmtFinSF2     1459           1     0.07  float64
# GarageArea     1459           1     0.07  float64
# BsmtFinSF1     1459           1     0.07  float64
# Exterior2nd    1459           1     0.07   object
# Exterior1st    1459           1     0.07   object

# %%
test_num = test.select_dtypes(exclude='object')
test_num = test_num.fillna(0)

# %%
test_quali = test.select_dtypes(include='object')
test_quali = test_quali.fillna('None')

# %%
test = pd.concat([test_quali, test_num], axis=1)

# %%
test.shape
# Out:
# (1459, 75)

# %%
test
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RH   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4          RL   Pave      IR1         HLS    AllPub    Inside       Gtl
# 5          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 6          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 7          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 8          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 9          RL   Pave      Reg         Lvl    AllPub    Corner       Gtl
# 10         RH   Pave      IR1         Lvl    AllPub       FR2       Gtl
# 11         RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 12         RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 13         RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 14         RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 15         RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 16         RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 17         RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 18         RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 19         RL   Pave      Reg         HLS    AllPub    Inside       Mod
# 20         RL   Pave      Reg         Lvl    AllPub    Corner       Gtl
# 21         RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 22         RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 23         RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 24         RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 25         RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 26         RL   Pave      IR2         Lvl    AllPub   CulDSac       Gtl
# 27         RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 28         FV   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 29         FV   Pave      Reg         Lvl    AllPub    Corner       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1429       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1430       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1431  C (all)   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1432  C (all)   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1433  C (all)   Grvl      Reg         Bnk    AllPub    Inside       Gtl
# 1434       RM   Pave      IR1         HLS    AllPub    Inside       Mod
# 1435       RM   Pave      IR1         HLS    AllPub    Inside       Mod
# 1436       RL   Pave      IR1         Lvl    AllPub    Inside       Mod
# 1437       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1438       RL   Pave      Reg         Lvl    AllPub    Corner       Gtl
# 1439       RL   Pave      Reg         Lvl    AllPub    Corner       Gtl
# 1440       RL   Pave      IR1         Low    AllPub    Inside       Mod
# 1441       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 1442       RL   Pave      Reg         Lvl    AllPub    Corner       Gtl
# 1443       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1444     None   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1445       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1446       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1447       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 1448       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 1449       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1450       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1451       RL   Pave      Reg         Lvl    AllPub    Inside       Mod
# 1452       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1453       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1454       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1455       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Mod
#
#      Neighborhood Condition1 Condition2  ... GarageArea WoodDeckSF  \
# 0           NAmes      Feedr       Norm  ...      730.0        140
# 1           NAmes       Norm       Norm  ...      312.0        393
# 2         Gilbert       Norm       Norm  ...      482.0        212
# 3         Gilbert       Norm       Norm  ...      470.0        360
# 4         StoneBr       Norm       Norm  ...      506.0          0
# 5         Gilbert       Norm       Norm  ...      440.0        157
# 6         Gilbert       Norm       Norm  ...      420.0        483
# 7         Gilbert       Norm       Norm  ...      393.0          0
# 8         Gilbert       Norm       Norm  ...      506.0        192
# 9           NAmes       Norm       Norm  ...      525.0        240
# 10          NAmes       Norm       Norm  ...      511.0        203
# 11         BrDale       Norm       Norm  ...      264.0        275
# 12         BrDale       Norm       Norm  ...      320.0          0
# 13        NPkVill       Norm       Norm  ...      440.0        173
# 14        NPkVill       Norm       Norm  ...      308.0          0
# 15        NridgHt       Norm       Norm  ...      751.0        144
# 16        NridgHt       Norm       Norm  ...      868.0          0
# 17        NridgHt       PosN       Norm  ...      730.0        192
# 18        NridgHt       Norm       Norm  ...      678.0          0
# 19        NridgHt       Norm       Norm  ...      958.0        220
# 20        NridgHt       Norm       Norm  ...      756.0        238
# 21        NridgHt       Norm       Norm  ...      484.0        120
# 22        Gilbert       Norm       Norm  ...      430.0         36
# 23        Blmngtn       Norm       Norm  ...      437.0        100
# 24        Gilbert       Norm       Norm  ...      400.0        100
# 25        Gilbert       Norm       Norm  ...      433.0        144
# 26        NoRidge       Norm       Norm  ...      962.0         23
# 27        Somerst       Norm       Norm  ...      880.0        144
# 28        Somerst       Norm       Norm  ...      676.0          0
# 29        Somerst       Norm       Norm  ...      528.0          0
# ...           ...        ...        ...  ...        ...        ...
# 1429       IDOTRR       Norm       Norm  ...      272.0        184
# 1430       IDOTRR       Norm       Norm  ...      384.0          0
# 1431       IDOTRR      Feedr       Norm  ...        0.0          0
# 1432       IDOTRR       Norm       Norm  ...        0.0          0
# 1433       IDOTRR       Norm       Norm  ...        0.0          0
# 1434      Crawfor       Norm       Norm  ...      495.0        123
# 1435      Crawfor       Norm       Norm  ...      525.0        128
# 1436      Mitchel       Norm       Norm  ...      576.0        136
# 1437      Mitchel       Norm       Norm  ...      616.0          0
# 1438      Mitchel       Norm       Norm  ...      490.0        120
# 1439      Mitchel       Norm       Norm  ...      528.0          0
# 1440       Timber       Norm       Norm  ...      518.0          0
# 1441       Timber       Norm       Norm  ...      470.0          0
# 1442       Timber       Norm       Norm  ...      714.0        172
# 1443       Timber       Norm       Norm  ...      682.0        161
# 1444      Mitchel     Artery       Norm  ...      270.0          0
# 1445      Mitchel       Norm       Norm  ...      784.0          0
# 1446      MeadowV       Norm       Norm  ...      336.0        141
# 1447      Mitchel       Norm       Norm  ...      288.0          0
# 1448      Mitchel       Norm       Norm  ...      928.0          0
# 1449      MeadowV       Norm       Norm  ...        0.0          0
# 1450      MeadowV       Norm       Norm  ...      253.0          0
# 1451      Mitchel       Norm       Norm  ...      336.0        160
# 1452      MeadowV       Norm       Norm  ...      286.0          0
# 1453      MeadowV       Norm       Norm  ...        0.0          0
# 1454      MeadowV       Norm       Norm  ...        0.0          0
# 1455      MeadowV       Norm       Norm  ...      286.0          0
# 1456      Mitchel       Norm       Norm  ...      576.0        474
# 1457      Mitchel       Norm       Norm  ...        0.0         80
# 1458      Mitchel       Norm       Norm  ...      650.0        190
#
#      OpenPorchSF EnclosedPorch 3SsnPorch ScreenPorch PoolArea MiscVal MoSold  \
# 0              0             0         0         120        0       0      6
# 1             36             0         0           0        0   12500      6
# 2             34             0         0           0        0       0      3
# 3             36             0         0           0        0       0      6
# 4             82             0         0         144        0       0      1
# 5             84             0         0           0        0       0      4
# 6             21             0         0           0        0     500      3
# 7             75             0         0           0        0       0      5
# 8              0             0         0           0        0       0      2
# 9              0             0         0           0        0       0      4
# 10            68             0         0           0        0       0      6
# 11             0             0         0           0        0       0      2
# 12             0             0         0           0        0       0      3
# 13             0             0         0           0        0       0      6
# 14            30             0         0           0        0       0      6
# 15           133             0         0           0        0       0      1
# 16            35             0         0           0        0       0      6
# 17            74             0         0           0        0       0      6
# 18           119             0         0           0        0       0      2
# 19           150             0         0           0        0       0      6
# 20           130             0         0           0        0       0      6
# 21            49             0         0           0        0       0      4
# 22            23             0         0           0        0       0      1
# 23           116             0         0           0        0       0      1
# 24             0             0         0           0        0       0      6
# 25            48             0         0           0        0       0      4
# 26           172             0         0         256        0       0      1
# 27             0             0         0           0        0       0      5
# 28           136             0         0           0        0       0      4
# 29           102             0         0         216        0       0      5
# ...          ...           ...       ...         ...      ...     ...    ...
# 1429           0            70         0           0        0       0      3
# 1430          21             0         0           0        0       0      4
# 1431           0            23         0           0        0       0     10
# 1432           0             0         0           0        0       0     10
# 1433           0             0         0           0        0       0      4
# 1434          53             0         0         153        0       0      2
# 1435          53             0         0         155        0       0     12
# 1436          28             0         0           0        0       0      9
# 1437           0             0         0           0        0       0     10
# 1438         100             0         0           0        0       0      5
# 1439           0             0         0           0        0       0      5
# 1440           0             0         0         138        0       0      3
# 1441         173             0         0           0        0       0     10
# 1442          38             0         0           0        0       0     11
# 1443         225             0         0           0        0       0      9
# 1444           0           135         0           0        0       0      5
# 1445          48             0         0           0        0       0     11
# 1446           0             0         0           0        0       0      5
# 1447         120             0         0           0        0       0     10
# 1448           0             0         0           0        0       0      3
# 1449           0             0         0           0        0       0      4
# 1450           0             0         0           0        0       0      5
# 1451           0             0         0           0        0       0      5
# 1452           0             0         0           0        0       0     12
# 1453          34             0         0           0        0       0      6
# 1454           0             0         0           0        0       0      6
# 1455          24             0         0           0        0       0      4
# 1456           0             0         0           0        0       0      9
# 1457          32             0         0           0        0     700      7
# 1458          48             0         0           0        0       0     11
#
#      YrSold
# 0      2010
# 1      2010
# 2      2010
# 3      2010
# 4      2010
# 5      2010
# 6      2010
# 7      2010
# 8      2010
# 9      2010
# 10     2010
# 11     2010
# 12     2010
# 13     2010
# 14     2010
# 15     2010
# 16     2010
# 17     2010
# 18     2010
# 19     2010
# 20     2010
# 21     2010
# 22     2010
# 23     2010
# 24     2010
# 25     2010
# 26     2010
# 27     2010
# 28     2010
# 29     2010
# ...     ...
# 1429   2006
# 1430   2006
# 1431   2006
# 1432   2006
# 1433   2006
# 1434   2006
# 1435   2006
# 1436   2006
# 1437   2006
# 1438   2006
# 1439   2006
# 1440   2006
# 1441   2006
# 1442   2006
# 1443   2006
# 1444   2006
# 1445   2006
# 1446   2006
# 1447   2006
# 1448   2006
# 1449   2006
# 1450   2006
# 1451   2006
# 1452   2006
# 1453   2006
# 1454   2006
# 1455   2006
# 1456   2006
# 1457   2006
# 1458   2006
#
# [1459 rows x 75 columns]

# %% [markdown]
# Nous avons à ce stade réaliser les mêmes traitements sur les datasets `train` et `test` qui sont :
#     - supprimer les features inutiles (trop de valeurs manquantes)
#     - traiter les valleurs nulles
